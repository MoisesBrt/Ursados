# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# D:\Programas\Anaconda\lib\site-packages\fastbook\__init__.py:19: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
key = os.environ.get('AZURE_SEARCH_KEY', 'bdc4c6cdcb0a4dc493b8fccd929d351f')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128, max_images=150)>

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 150

# %%
#hide
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='704512' class='' max='697626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.99% [704512/697626 00:00<00:00]
#     </div>
# Path('images/grizzly.jpg')

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128 at 0x2610C6C73A0>

# %%
bear_types = 'grizzly','black','teddy','polar'
path = Path('bears')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bear')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#428) [Path('bears/black/00000000.JPG'),Path('bears/black/00000002.jpg'),Path('bears/black/00000003.jpg'),Path('bears/black/00000004.jpg'),Path('bears/black/00000006.jpg'),Path('bears/black/00000008.jpg'),Path('bears/black/00000010.jpeg'),Path('bears/black/00000011.jpg'),Path('bears/black/00000012.jpeg'),Path('bears/black/00000013.jpeg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#2) [Path('bears/grizzly/00000095.jpeg'),Path('bears/polar/00000074.jpg')]

# %%
failed.map(Path.unlink);

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# D:\Programas\Anaconda\lib\site-packages\torch\_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ..\aten\src\ATen\native\BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.706840</td>
#       <td>0.148826</td>
#       <td>0.047059</td>
#       <td>01:14</td>
#     </tr>
#   </tbody>
# </table>
# D:\Programas\Anaconda\lib\site-packages\PIL\Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# D:\Programas\Anaconda\lib\site-packages\PIL\TiffImagePlugin.py:819: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.230096</td>
#       <td>0.167643</td>
#       <td>0.047059</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.144173</td>
#       <td>0.140660</td>
#       <td>0.023529</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.122528</td>
#       <td>0.149588</td>
#       <td>0.023529</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.098030</td>
#       <td>0.145192</td>
#       <td>0.023529</td>
#       <td>01:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
#hide_output
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('black', 'grizzly', 'polar', 'teddy'), value='black'), Dropdown(options=('Tra…

# %%
#hide
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
learn.export()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18068/1466232964.py in <module>
# ----> 1 learn.export()
#
# NameError: name 'learn' is not defined

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')
# Out:
# ('grizzly',
#  TensorBase(1),
#  TensorBase([2.9291e-06, 9.9999e-01, 1.7214e-06, 4.8196e-07]))

# %%
learn_inf.dls.vocab
# Out:
# ['black', 'grizzly', 'polar', 'teddy']

# %%
#hide_output
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
#hide_output
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
#hide_output
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 1.0000')

# %%
#hide_output
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
#hide_output
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={'Aula 17-01-2022 .txt': {'metadata': {'name…

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.3.1-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: jupyter-client<8,>=6.1.3 in d:\programas\anaconda\lib\site-packages (from voila) (6.1.12)
# Collecting nbconvert<7,>=6.0.0
#   Downloading nbconvert-6.4.2-py3-none-any.whl (558 kB)
# Collecting websockets>=9.0
#   Downloading websockets-10.1-cp39-cp39-win_amd64.whl (97 kB)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in d:\programas\anaconda\lib\site-packages (from voila) (0.5.3)
# Requirement already satisfied: traitlets<6,>=5.0.3 in d:\programas\anaconda\lib\site-packages (from voila) (5.1.0)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in d:\programas\anaconda\lib\site-packages (from voila) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in d:\programas\anaconda\lib\site-packages (from jupyter-client<8,>=6.1.3->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in d:\programas\anaconda\lib\site-packages (from jupyter-client<8,>=6.1.3->voila) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\programas\anaconda\lib\site-packages (from jupyter-client<8,>=6.1.3->voila) (4.8.1)
# Requirement already satisfied: tornado>=4.1 in d:\programas\anaconda\lib\site-packages (from jupyter-client<8,>=6.1.3->voila) (6.1)
# Requirement already satisfied: pywin32>=1.0 in d:\programas\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8,>=6.1.3->voila) (228)
# Requirement already satisfied: terminado>=0.8.3 in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.4)
# Requirement already satisfied: anyio>=2.0.2 in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.2.0)
# Requirement already satisfied: Send2Trash in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.8.0)
# Requirement already satisfied: jinja2 in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.11.3)
# Requirement already satisfied: ipython-genutils in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: prometheus-client in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.11.0)
# Requirement already satisfied: nbformat in d:\programas\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (5.1.3)
# Requirement already satisfied: idna>=2.8 in d:\programas\anaconda\lib\site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (3.2)
# Requirement already satisfied: sniffio>=1.1 in d:\programas\anaconda\lib\site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (1.2.0)
# Requirement already satisfied: async-generator in d:\programas\anaconda\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: nest-asyncio in d:\programas\anaconda\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.5.1)
# Requirement already satisfied: jupyterlab-pygments in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: bleach in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (4.0.0)
# Requirement already satisfied: pygments>=2.4.1 in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.10.0)
# Requirement already satisfied: testpath in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.3)
# Requirement already satisfied: defusedxml in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\programas\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programas\anaconda\lib\site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\programas\anaconda\lib\site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in d:\programas\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (1.16.0)
# Requirement already satisfied: setuptools in d:\programas\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in d:\programas\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\programas\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.18.0)
# Requirement already satisfied: pywinpty>=0.5 in d:\programas\anaconda\lib\site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.5.7)
# Requirement already satisfied: packaging in d:\programas\anaconda\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (21.0)
# Requirement already satisfied: webencodings in d:\programas\anaconda\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programas\anaconda\lib\site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (3.0.4)
# Installing collected packages: nbconvert, websockets, voila
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# Successfully installed nbconvert-6.4.2 voila-0.3.1 websockets-10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# nbdev 1.1.23 requires nbconvert<6, but you have nbconvert 6.4.2 which is incompatible.
# Enabling: voila
# - Writing config: D:\Programas\Anaconda\etc\jupyter
#     - Validating...
#       voila 0.3.1 ok
